# %%
# %sql
SELECT * FROM parquet.`/Volumes/software/bronze/bronzevolume/customers/`

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("/Volumes/software/bronze/bronzevolume/customers/")

# %%
df.display()
